# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Захар, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Спасибо за ревью! Были проблемы с платформой, почему-то отправился не законченный вариант тетрадки.

# %% [markdown]
# ### Цели и задачи проекта
# **Цель:** Провести исследовательский анализ для Яндекс Афиши с целью понимания какие пользователи с большей вероятностью возвращаются на платформу для повторных заказов.
#
# **Задачи:**
# 1. Загрузить данные и ознакомиться с ними
# 2. Предобработка данных
# 3. Провести исследовательский анализ данных
# 4. Формирование выводов и рекомендаций

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### 1. Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные. Используйте следующие параметры для подключения к базе данных `data-analyst-afisha`:
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# Загрузим основные библиотеки. Приконнектимся к базе данных и передадим SQL запрос. Далее выгрузим его в датафрейм `df`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import phik
from IPython.display import display
from matplotlib.ticker import MultipleLocator
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

from sqlalchemy import create_engine

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали, коннектор сделали - отлично!

# %%
import os
from dotenv import load_dotenv
load_dotenv('connect.env')

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    os.getenv('DB_USER'),
    os.getenv('DB_PASSWORD'),
    os.getenv('DB_HOST'),
    os.getenv('DB_PORT'),
    os.getenv('DB_NAME'),
)


engine = create_engine(connection_string)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Обрати внимание, что версия с `load_dotenv` должна быть только в `GitHub` - для проекта на платформе параметры подключения нужно указывать явно, иначе не получится подключиться к базе.

# %%
query = '''
SELECT p.user_id,
       p.device_type_canonical,
       p.order_id,
       p.created_dt_msk AS order_dt,
       p.created_ts_msk AS order_ts,
       p.currency_code,
       p.revenue,
       p.tickets_count,
       EXTRACT(DAY FROM(created_dt_msk - LAG(created_dt_msk) OVER (PARTITION BY user_id ORDER BY created_dt_msk))) AS days_since_prev, 
       e.event_id,
       e.event_name_code AS event_name,
       p.service_name,
       e.event_type_main,
       r.region_name,
       c.city_name
FROM afisha.purchases AS p
INNER JOIN afisha.events AS e ON e.event_id = p.event_id
INNER JOIN afisha.city AS c ON c.city_id = e.city_id
INNER join afisha.regions AS r ON r.region_id = c.region_id
WHERE (p.device_type_canonical = 'mobile' OR p.device_type_canonical = 'desktop') AND event_type_main != 'фильм'
ORDER BY p.user_id;
'''

# %%
df = pd.read_sql_query(query, con=engine)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные выгружены из базы.

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %% [markdown]
# Выведем информацию о датафрейме:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  service_name           290611 non-null  object
#  12  event_type_main        290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %%
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name        service_name  \
# ...

# %% [markdown]
# #### Промежуточный вывод:
# Датафрейм `df` содержит:
# 1. Количество строк - 290611. Количество столбцов - 15;
# 2. Пропуски встречаются только в столбце `days_since_prev` это обусловлено тем, что это могут быть новые пользователи платформы и у них нет предыдущих заказов;
# 3. Тип `object` у колонок: `user_id`, `device_type_canonical`, `currency_code`, `event_name`, `service_name`, `event_type_main`, `region_name` и `city_name`;
# 4. Тип `int64` у колонок: `order_id`, `tickets_count` и `event_id`;
# 5. Тип `float64` у колонок: `revenue` и `days_since_prev`;
# 6. Тип `datetime64[ns]` у колонок: `order_dt` и `order_ts`.

# %% [markdown]
# Необходимо обработать данные:
# 1. Привести все суммы к рублю;
# 2. Оптимизировать типы данных;
# 3. Проверить на явные и неявные дубликаты;
# 4. Проверить на пропуски;

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выполнен первичный анализ данных.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Нужно наметить направления по их обработке.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Выполним предобработку данных:

# %% [markdown]
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %% [markdown]
# Объединим два датафрейма в один:

# %%
df_exchange = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')
df_exchange.head()
# Out:
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %%
df_exchange['data'] = pd.to_datetime(df_exchange['data'])
df_merged = df.merge(df_exchange, left_on=['order_dt'], right_on = ['data'], how='inner')

# %%
df_merged.loc[df_merged['currency_code'] == 'kzt', 'revenue_rub'] = ((df_merged['revenue'] / 100) * df_merged['curs'])
df_merged.loc[df_merged['currency_code'] != 'kzt', 'revenue_rub'] = df_merged['revenue']

# %% [markdown]
# Удалим ненужные столбцы:

# %%
columns_to_drop = ['data','curs','nominal','cdx']
df_merged = df_merged.drop(columns = columns_to_drop)
df_merged.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name        service_name  \
# ...

# %% [markdown]
# Получили интересующий нас датафрейм.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выручка приведена к единой валюте. Отлично, что используешь маски вместо `apply()`.

# %% [markdown]
# ---
#
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %% [markdown]
# Выведем типы столбцов:

# %%
df_merged.dtypes
# Out:
# user_id                          object
# device_type_canonical            object
# order_id                          int64
# order_dt                 datetime64[ns]
# order_ts                 datetime64[ns]
# currency_code                    object
# revenue                         float64
# tickets_count                     int64
# days_since_prev                 float64
# event_id                          int64
# event_name                       object
# service_name                     object
# event_type_main                  object
# region_name                      object
# city_name                        object
# revenue_rub                     float64
# dtype: object

# %% [markdown]
# Узнаем количество пропусков в датафрейме:

# %%
df_merged.isna().sum()
# Out:
# user_id                      0
# device_type_canonical        0
# order_id                     0
# order_dt                     0
# order_ts                     0
# currency_code                0
# revenue                      0
# tickets_count                0
# days_since_prev          21933
# event_id                     0
# event_name                   0
# service_name                 0
# event_type_main              0
# region_name                  0
# city_name                    0
# revenue_rub                  0
# dtype: int64

# %%
df_merged.isna().mean()
# Out:
# user_id                  0.000000
# device_type_canonical    0.000000
# order_id                 0.000000
# order_dt                 0.000000
# order_ts                 0.000000
# currency_code            0.000000
# revenue                  0.000000
# tickets_count            0.000000
# days_since_prev          0.075472
# event_id                 0.000000
# event_name               0.000000
# service_name             0.000000
# event_type_main          0.000000
# region_name              0.000000
# city_name                0.000000
# revenue_rub              0.000000
# dtype: float64

# %% [markdown]
# Пропуски есть только в столбце `days_since_prev` это обусловлено тем, что пользователи на платформе раньше не бронировали билеты.
# Количество пропусков - 21 933.
#
# Доля пропусков 7.5%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пропуски исследованы.

# %% [markdown]
# Проверим данные на явные и неявные дубликаты:

# %%
df_merged.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Проверим данные на дубликаты в столбце `order_id`:

# %%
df_merged.duplicated(subset='order_id').sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Подскажи, действительно ли нам нужна тут нормализация? Какую проблему она позволяет нам решить?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Теоретически - да. Практически, применительно к нашему кейсу, она нужна? Ты меняешь названия региона и партнёра - это юридически значимые сущности. Чтобы был какой-то резон их менять, там должны быть явные ошибки. У нас они есть?

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
df_merged.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# После предобработки данных не было обнаружено явных и неявных дубликатов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проверены дубликаты в данных.

# %% [markdown]
# Проверим уникальные значения категориальных данных:

# %%
for column in ['service_name', 'event_type_main','region_name', 'city_name','currency_code']:
    np.set_printoptions(threshold=np.inf) 
    print(f'Уникальные значения в столбце {column}:')
    print(df_merged[column].sort_values().unique())
    print()
# Out:
# Уникальные значения в столбце service_name:
# ['Crazy ticket!' 'Show_ticket' 'Билет по телефону' 'Билеты без проблем'
#  'Билеты в интернете' 'Билеты в руки' 'Быстробилет' 'Быстрый кассир'
#  'Весь в билетах' 'Восьмёрка' 'Вперёд!' 'Выступления.ру'
#  'Городской дом культуры' 'Дом культуры' 'Дырокол' 'За билетом!'
#  'Зе Бест!' 'КарандашРУ' 'Кино билет' 'Край билетов' 'Лимоны'
#  'Лови билет!' 'Лучшие билеты' 'Мир касс' 'Мой билет' 'Облачко'
#  'Прачечная' 'Радио ticket' 'Реестр' 'Росбилет' 'Тебе билет!' 'Телебилет'
#  'Тех билет' 'Цвет и билет' 'Шоу начинается!' 'Яблоко']
#
# Уникальные значения в столбце event_type_main:
# ['выставки' 'другое' 'концерты' 'спорт' 'стендап' 'театр' 'ёлки']
#
# Уникальные значения в столбце region_name:
# ['Белоярская область' 'Берестовский округ' 'Берёзовская область'
#  'Боровлянский край' 'Верховинская область' 'Верхозёрский край'
#  'Верхоречная область' 'Ветренский регион' 'Вишнёвский край'
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Категориальные признаки проверены на предмет аномалий.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Нужно сделать вывод - есть ли что-то, на что нужно обратить внимание, нужна ли нормазиация?

# %% [markdown]
# В столбце `service_name` присутствуют значения имеющие спец символы, в данном случае, `!`. Возможно, что это не ошибка и не опечатка, а реальные названия сервисов, но проверить мы это не можем.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Восклицательные знаки могут быть рекламном имени, так что это не ошибка.

# %% [markdown]
# Сделаем оптимизацию датафрейма:

# %%
df_optimazed = df_merged.copy()
columns_to_astype = ['device_type_canonical' , 'currency_code','event_type_main']
for col in columns_to_astype:
    df_optimazed[col] = df_optimazed[col].astype('category')
    
df_optimazed['tickets_count'] = df_optimazed['tickets_count'].astype('int8')

df_optimazed['days_since_prev'] = df_optimazed['days_since_prev'].astype('UInt16')
df_optimazed.dtypes
# Out:
# user_id                          object
# device_type_canonical          category
# order_id                          int64
# order_dt                 datetime64[ns]
# order_ts                 datetime64[ns]
# currency_code                  category
# revenue                         float64
# tickets_count                      int8
# days_since_prev                  UInt16
# event_id                          int64
# event_name                       object
# service_name                     object
# event_type_main                category
# region_name                      object
# city_name                        object
# revenue_rub                     float64
# dtype: object

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Типы данных оптимизированы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Заполнение пропусков значением `-1` приведёт к искажению анализа распределения, среднего интервала и корреляции - пропуски стоит оставить без изменений.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Проверим распределение численных данных и наличие в них выбросов в столбцах `revenue_rub` и `tickets_count`:

# %%
plt.figure(figsize=(10,4))
df_optimazed.boxplot(column='tickets_count', vert=False)
plt.title('Боксплот количества купленных билетов')
plt.xlabel('Количество билетов')
plt.ylabel('')
plt.show()

# %% [markdown]
# Присутствуют выбросы количества билетов на боксплоте. Это может быть обусловлено ошибкой в данных или покупокой билетов на большое количество людей.

# %%
plt.figure(figsize=(10,4))
df_optimazed.boxplot(column='revenue_rub', vert=False)
plt.title('Боксплот стоимости заказа')
plt.xlabel('Стоимость заказа')
plt.ylabel('')
plt.show()

# %% [markdown]
# Выбросы в стоимости заказа могут быть обусловлены ошибкой в данных или это заказ на большое количество людей.

# %%
q99 = df_optimazed['revenue_rub'].quantile(0.99)
df_filtered = df_optimazed[df_optimazed['revenue_rub'] <= q99].copy()
print(f"Удалено {len(df_optimazed) - len(df_filtered)} строк или {(1 - len(df_filtered)/len(df_optimazed))*100:.2f}%")
# Out:
# Удалено 2825 строк или 0.97%

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Численные признаки изучены, удалены выбросы.

# %% [markdown]
# **Промежуточный вывод:**
#
# Добавили новый столбец `revenue_rub` в котором все данные со столбца `revenue` приведены к рублям.
#
# После предобработки не было выявлено явных и неявных дубликатов. Также вывели все уникальные значения в категориальных столбцах.
#
# Заменили пропуски в столбце `days_since_prev` на `-1`.
#
# Оптимизировали типы данных в датафрейме.
#
# Выявили выбросы в интересующих нас столбцах `revenue_rub` и `tickets_count`. Отфильтровали датафрейм по 99 процентилю по столбцу `revenue_rub`.
#
# Датафрейм уменьшился на 2825 строк или на 0.97%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отлично, что деаешь промежуточный вывод с оценкой потерь после обработки.

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
df_filtered = df_filtered.sort_values('order_ts')

# %%
user_profiles = df_filtered.groupby('user_id').agg(
    first_order = ('order_dt', 'min'),
    last_order = ('order_dt', 'max'),
    device = ('device_type_canonical', 'first'),
    region = ('region_name', 'first'),
    service_name = ('service_name', 'first'),
    genre_event = ('event_type_main', 'first'),
    total_orders = ('order_id', 'size'),
    avg_order_costs = ('revenue_rub', 'mean'),
    avg_tickets_count=('tickets_count', 'mean'),
    avg_days_since_prev = ('days_since_prev', 'mean')
).reset_index()
user_profiles['is_two'] = user_profiles['total_orders'] >= 2
user_profiles['is_five'] = user_profiles['total_orders'] >=5

user_profiles['avg_order_costs'] = user_profiles['avg_order_costs'].round(2)
user_profiles['avg_tickets_count'] = user_profiles['avg_tickets_count'].round(2)
user_profiles['avg_days_since_prev'] = user_profiles['avg_days_since_prev']

user_profiles.head()
# Out:
#            user_id first_order last_order   device                region  \
# 0  0002849b70a3ce2  2024-08-20 2024-08-20   mobile    Каменевский регион
# 1  0005ca5e93f2cf4  2024-07-23 2024-10-06   mobile    Каменевский регион
# 2  000898990054619  2024-07-13 2024-10-23   mobile  Североярская область
# 3  00096d1f542ab2b  2024-08-15 2024-08-15  desktop    Каменевский регион
# 4  000a55a418c128c  2024-09-29 2024-10-15   mobile      Поленовский край
#
#     service_name genre_event  total_orders  avg_order_costs  \
# 0   Край билетов       театр             1          1521.94
# 1      Мой билет    выставки             2           774.01
# 2    Лови билет!      другое             3           767.21
# 3   Край билетов       театр             1           917.83
# 4  Лучшие билеты       театр             2            61.31
#
#    avg_tickets_count  avg_days_since_prev  is_two  is_five
# 0               4.00                 <NA>   False    False
# ...

# %% [markdown]
# Профиль пользователя создан.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Создан профиль пользователя, добавлены бинарные признаки.

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
total_users = user_profiles['user_id'].agg('size')
print('Общее количество пользователей в выборке:', total_users)
print('Средняя выручка с одного заказа в рублях:', user_profiles['avg_order_costs'].mean().round(2))
print('Доля пользователей, совершивших 2 и более заказа:', ((user_profiles['is_two'].sum() / total_users)*100).round(2)) 
print('Доля пользователей, совершивших 5 и более заказов:', ((user_profiles['is_five'].sum() / total_users)*100).round(2))
# Out:
# Общее количество пользователей в выборке: 21854
# Средняя выручка с одного заказа в рублях: 544.4
# Доля пользователей, совершивших 2 и более заказа: 61.71
# Доля пользователей, совершивших 5 и более заказов: 29.01

# %%
print('Статистика по общему числу заказов:', user_profiles['total_orders'].describe())
print('Статистика по среднему числу билетов в заказе:', user_profiles['avg_tickets_count'].describe())
filtered_days = user_profiles[user_profiles['avg_days_since_prev'] >= 0]['avg_days_since_prev']
print('Статистика по среднему количеству дней между покупками:', filtered_days.describe())
# Out:
# Статистика по общему числу заказов: count    21854.000000
# mean        13.168573
# std        121.674800
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10181.000000
# Name: total_orders, dtype: float64
# Статистика по среднему числу билетов в заказе: count    21854.000000
# mean         2.743136
# std          0.913090
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.080000
# max         11.000000
# Name: avg_tickets_count, dtype: float64
# Статистика по среднему количеству дней между покупками: count      13513.0
# mean     15.851275
# std      22.306224
# min            0.0
# 25%            1.0
# 50%            8.0
# 75%      20.428571
# max          148.0
# Name: avg_days_since_prev, dtype: Float64

# %% [markdown]
# После сбора статистики по столбцам `total_orders`, `avg_tickets_count` и `avg_days_since_prev` выявили выбросы в столбце `total_orders`. Максимальное значение в стоблце `total_orders` составляет 10181, это может быть обусловлено ошибкой в данных, аномалий или это корпоративный аккаунт.

# %% [markdown]
# Визуализируем статистику по каждому столбцу:

# %%
plt.figure(figsize=(10,4))
user_profiles.boxplot(column='total_orders', vert=False)
plt.title('Боксплот количества заказов')
plt.xlabel('Количество заказов')
plt.ylabel('')
plt.show()

# %% [markdown]
# Ярко выражен выброс.

# %%
plt.figure(figsize=(10,4))
user_profiles.boxplot(column='avg_tickets_count', vert=False)
plt.title('Боксплот среднего числа билетов в заказе')
plt.xlabel('Среднее число билетов в заказе')
plt.ylabel('')
plt.show()

# %%
filtered_days_df = user_profiles[user_profiles['avg_days_since_prev'] >= 0]
plt.figure(figsize=(10,4))
filtered_days_df.boxplot(column='avg_days_since_prev', vert=False)
plt.title('Боксплот среднего количества дней между покупками')
plt.xlabel('Среднее количество дней между покупками')
plt.ylabel('')
plt.show()

# %% [markdown]
# Отфильтруем данные в столбце `total_orders` по 99 процентилю, чтобы оставить больше рабочих данных.

# %%
total_orders = user_profiles['total_orders'].quantile(0.99)
user_profiles_filtered = user_profiles[user_profiles['total_orders'] <= total_orders].copy()

original = len(user_profiles)
filtered = len(user_profiles_filtered)
removed = original - filtered
print(f"Оригинальный датасет: {original} пользователей")
print(f"После фильтрации: {filtered} пользователей")
print(f"Отфильтровано: {removed} пользователей ({removed / original * 100:.2f}%)")
# Out:
# Оригинальный датасет: 21854 пользователей
# После фильтрации: 21638 пользователей
# Отфильтровано: 216 пользователей (0.99%)

# %%
print('Статистика по общему числу заказов:', user_profiles_filtered['total_orders'].describe())
print('Статистика по среднему числу билетов в заказе:', user_profiles_filtered['avg_tickets_count'].describe())
filtered_days = user_profiles_filtered[user_profiles_filtered['avg_days_since_prev'] >= 0]['avg_days_since_prev']
print('Статистика по среднему количеству дней между покупками:', filtered_days.describe())
# Out:
# Статистика по общему числу заказов: count    21638.000000
# mean         6.501294
# std         14.324031
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max        152.000000
# Name: total_orders, dtype: float64
# Статистика по среднему числу билетов в заказе: count    21638.000000
# mean         2.743327
# std          0.917496
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.100000
# max         11.000000
# Name: avg_tickets_count, dtype: float64
# Статистика по среднему количеству дней между покупками: count      13297.0
# mean     16.101314
# std      22.399512
# min            0.0
# 25%       1.333333
# 50%       8.352941
# 75%          20.75
# max          148.0
# Name: avg_days_since_prev, dtype: Float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Изучены статистики по профилю пользователя, удалены выбросы.

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
segment_event_type = user_profiles_filtered.groupby('genre_event')['user_id'].agg('count').reset_index(name = 'user_count')
segment_event_type['share'] = (segment_event_type['user_count'] / segment_event_type['user_count'].sum()).round(2)
display(segment_event_type.sort_values('user_count', ascending=False))
# Out:
#   genre_event  user_count  share
# 2    концерты        9560   0.44
# 1      другое        5426   0.25
# 5       театр        4239   0.20
# 4     стендап        1110   0.05
# 3       спорт         794   0.04
# 0    выставки         414   0.02
# 6        ёлки          95   0.00

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Метод `.print()` не очень подходит для работы с таблицами типа `pd.DataFrame`, так как выводит их на экран просто как отформатированный текст. Для отображения небольших таблиц можно воспользоваться методом `.head()`, для таблиц побольше - модулем `display`.
#
# </div>

# %%
segment_device_type = user_profiles_filtered.groupby('device')['user_id'].agg('count').reset_index(name = 'user_count')
segment_device_type['share'] = (segment_device_type['user_count'] / segment_device_type['user_count'].sum()).round(2)
segment_device_type.sort_values('user_count', ascending=False).head()
# Out:
#     device  user_count  share
# 1   mobile       17924   0.83
# 0  desktop        3714   0.17

# %%
segment_region_type = user_profiles_filtered.groupby('region')['user_id'].agg('count').reset_index(name = 'user_count')
segment_region_type['share'] = (segment_region_type['user_count'] / segment_region_type['user_count'].sum()).round(2)
display(segment_region_type.sort_values('user_count', ascending=False))
# Out:
#                       region  user_count  share
# 23        Каменевский регион        7085   0.33
# 60      Североярская область        3767   0.17
# 77       Широковская область        1224   0.06
# 45          Озернинский край         675   0.03
# 41      Малиновоярский округ         525   0.02
# ..                       ...         ...    ...
# 17            Залесский край           2   0.00
# 70       Тихогорская область           2   0.00
# 5          Верхозёрский край           1   0.00
# 66  Сосноводолинская область           1   0.00
# 80        Яснопольский округ           1   0.00
#
# [81 rows x 3 columns]

# %%
segment_service_name_type = user_profiles_filtered.groupby('service_name')['user_id'].agg('count').reset_index(name = 'user_count')
segment_service_name_type['share'] = (segment_service_name_type['user_count'] / segment_service_name_type['user_count'].sum()).round(2)
display(segment_service_name_type.sort_values('user_count', ascending=False))
# Out:
#               service_name  user_count  share
# 3       Билеты без проблем        5186   0.24
# 22               Мой билет        2969   0.14
# 19             Лови билет!        2809   0.13
# 4            Билеты в руки        2559   0.12
# 23                 Облачко        2177   0.10
# 7           Весь в билетах        1285   0.06
# 20           Лучшие билеты        1184   0.05
# 24               Прачечная         583   0.03
# 17            Край билетов         454   0.02
# 12            Дом культуры         356   0.02
# 33                  Яблоко         318   0.01
# 28             Тебе билет!         308   0.01
# 11  Городской дом культуры         215   0.01
# 21                Мир касс         209   0.01
# 13             За билетом!         201   0.01
# 5              Быстробилет         162   0.01
# 1              Show_ticket         157   0.01
# 10          Выступления.ру          95   0.00
# 8                Восьмёрка          85   0.00
# ...

# %% [markdown]
# Промежуточный вывод:
#
# Пользователи распределены неравномерно в каждом из сегментов. Есть явные лидеры и аутсайдеры. Ниже перечислены лидеры в каждом сегменте:
#
# 1. Сегмент по типу ивентов - на `концерты` покупают билеты наибольшее количество пользователей (9560 человек или 0.44 от всего количества пользователей) чем на другие ивенты.
# 2. Сегмент по региону - `каменевский_регион` наиболее популярный у пользователей, 7085 пользователей или 0.33 от всего количества пользователей.
# 3. Сегмент по типу девайса - количество заказов совершенный через мобильное устройство намного больше чем с десктопного, 17924 человек или 0.83 от всего количества пользователей.
# 4. Сегмент по билетному оператору - наибольшее количество пользователей приобрели билеты через сервис `билеты_без_проблем`, 5186 человек или 0.24 от всего количества пользователей.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно выполнил группировку пользователей по всем четырем признакам, указанным в задании. Данные перенесены из таблиц корректно: количество пользователей и их доли для топовых сегментов - концерты, каменевский_регион, мобильные устройства и билеты_без_проблем - полностью совпадают с таблицами.
#
# Также ты правильно определил «точки входа» - сегменты с максимальным числом пользователей. Основной вывод о том, какие категории лидируют, сделан верно.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Стоит обратить внимание на формулировки. В задании просили группировать по билетному оператору, а в выводе ты назвал это типом сервиса. Лучше придерживаться терминологии задания, чтобы избежать путаницы.
#
# В выводе по регионам ты выдвинул гипотезу, что в Каменевском регионе проводится больше всего ивентов. Это логичное предположение, но таблицы показывают только распределение пользователей, а не количество мероприятий. Лучше описывать только то, что есть в цифрах, или помечать это как личное предположение.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Также в задании был прямой вопрос: равномерно ли распределены пользователи. Ты перечислил лидеров, но не дал обобщающего ответа (например, что распределение везде неравномерное и есть явные перекосы). Стоит проговаривать этот момент явно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
filtered_is_two = user_profiles_filtered[user_profiles_filtered['is_two'] == True]
total_counts = user_profiles_filtered.groupby('genre_event')['user_id'].agg('count').reset_index(name = 'total_count')
two_counts = filtered_is_two.groupby('genre_event')['user_id'].agg('count').reset_index(name = 'two_count')
merged = total_counts.merge(two_counts, on = 'genre_event', how = 'left')
merged['share'] = (merged['two_count'] / merged['total_count']).round(2)
result_1 = merged.sort_values('two_count', ascending=False).reset_index(drop=True)
print(result_1)


plt.figure(figsize=(14,8))

result_1.plot(
               x = 'genre_event',
               y = 'two_count',
               kind='bar',
               rot=0,
               legend=False,
               title=f'Количество вернувшихся пользователей по категориям мероприятий')

plt.xlabel('Тип мероприятия')
plt.ylabel('Количество вернувшихся пользователей')
plt.grid()
plt.show()
# Out:
#   genre_event  total_count  two_count  share
# 0    концерты         9560       5911   0.62
# 1      другое         5426       3235   0.60
# 2       театр         4239       2687   0.63
# 3     стендап         1110        676   0.61
# 4       спорт          794        443   0.56
# 5    выставки          414        265   0.64
# 6        ёлки           95         53   0.56

# %%
total_counts = user_profiles_filtered.groupby('device')['user_id'].agg('count').reset_index(name = 'total_count')
two_counts = filtered_is_two.groupby('device')['user_id'].agg('count').reset_index(name = 'two_count')
merged = total_counts.merge(two_counts, on = 'device', how = 'left')
merged['share'] = (merged['two_count'] / merged['total_count']).round(2)
result_2 = merged.sort_values('two_count', ascending=False).reset_index(drop=True)
print(result_2)

plt.figure(figsize=(14,8))

result_2.plot(
               x = 'device',
               y = 'two_count',
               kind='bar',
               rot=0,
               legend=False,
               title=f'Количество вернувшихся пользователей по категориям устройства')

plt.xlabel('Тип устройства')
plt.ylabel('Количество вернувшихся пользователей')
plt.grid()
plt.show()
# Out:
#     device  total_count  two_count  share
# 0   mobile        17924      10900   0.61
# 1  desktop         3714       2370   0.64

# %%
total_counts = user_profiles_filtered.groupby('region')['user_id'].agg('count').reset_index(name = 'total_count')
two_counts = filtered_is_two.groupby('region')['user_id'].agg('count').reset_index(name = 'two_count')
merged = total_counts.merge(two_counts, on = 'region', how = 'left')
merged['share'] = (merged['two_count'] / merged['total_count']).round(2)
result_3 = merged.sort_values('two_count', ascending=False).reset_index(drop=True)
print(result_3)

result_3.head(10).plot(
               x = 'region',
               y = 'two_count',
               kind='bar',
               rot=90,
               legend=False,
               title=f'Количество вернувшихся пользователей по названиям регионов')

plt.xlabel('Название региона')
plt.ylabel('Количество вернувшихся пользователей')
plt.grid()
plt.show()
# Out:
#                       region  total_count  two_count  share
# 0         Каменевский регион         7085     4421.0   0.62
# 1       Североярская область         3767     2404.0   0.64
# 2        Широковская область         1224      790.0   0.65
# 3           Озернинский край          675      373.0   0.55
# 4           Шанырский регион          500      336.0   0.67
# ..                       ...          ...        ...    ...
# 76      Островогорский округ            5        1.0   0.20
# 77       Тихогорская область            2        1.0   0.50
# 78       Теплоозёрский округ            3        1.0   0.33
# 79  Сосноводолинская область            1        NaN    NaN
# 80        Яснопольский округ            1        NaN    NaN
#
# [81 rows x 4 columns]

# %%
total_counts = user_profiles_filtered.groupby('service_name')['user_id'].agg('count').reset_index(name = 'total_count')
two_counts = filtered_is_two.groupby('service_name')['user_id'].agg('count').reset_index(name = 'two_count')
merged = total_counts.merge(two_counts, on = 'service_name', how = 'left')
merged['share'] = (merged['two_count'] / merged['total_count']).round(2)
result_4 = merged.sort_values('two_count', ascending=False).reset_index(drop=True)
print(result_4)


result_4.head(10).plot(
               x = 'service_name',
               y = 'two_count',
               kind='bar',
               rot=90,
               legend=False,
               title=f'Количество вернувшихся пользователей по названиям сервисов')

plt.xlabel('Название сервиса')
plt.ylabel('Количество вернувшихся пользователей')
plt.grid()
plt.show()
# Out:
#               service_name  total_count  two_count  share
# 0       Билеты без проблем         5186       3133   0.60
# 1                Мой билет         2969       1807   0.61
# 2              Лови билет!         2809       1711   0.61
# 3            Билеты в руки         2559       1605   0.63
# 4                  Облачко         2177       1334   0.61
# 5           Весь в билетах         1285        808   0.63
# 6            Лучшие билеты         1184        725   0.61
# 7                Прачечная          583        365   0.63
# 8             Край билетов          454        296   0.65
# 9             Дом культуры          356        230   0.65
# 10             Тебе билет!          308        186   0.60
# 11                  Яблоко          318        170   0.53
# 12                Мир касс          209        135   0.65
# 13  Городской дом культуры          215        126   0.59
# 14             За билетом!          201        118   0.59
# ...

# %% [markdown]
# Чаще всего пользователи которые возвращаюся на платформу Яндекс Афиша:
# 1. Делают заказы через `мобильное приложение`.
# 2. Используют сервис `билеты_без_проблем`.
# 3. Место проведения мероприятия в `каменевский_регион`.
# 4. Выбирают тип мероприятия `концерты`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Доли возврата посчитаны неверно - мы должны по каждому значению категориального признака посчитать общее число пользователей и число пользователей с `is_two=True`. Доля возврата - это отношение второго к первому. Текущий расчёт не отличается от расчёта в предыдущем задании - по факту посчитано распределение пользователей с `is_two=True`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут актуально.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %% [markdown]
# Проверим первую гипотезу.

# %%
plt.figure(figsize=(14,8))

result_1.plot(
               x = 'genre_event',
               y = 'share',
               kind='bar',
               rot=0,
               legend=False,
               title=f'Доля вернувшихся пользователей по категориям мероприятий')

plt.xlabel('Тип мероприятия')
plt.ylabel('Доля вернувшихся пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Пользователи которые сделали свой первый заказ на `концерты` возвращаются на платформу чаще чем пользователи выбравшие для первого раза `спортивные` мероприятия. Гипотеза неверна.

# %% [markdown]
# Проверим вторую гипотезу.

# %%
result_3.head(10).plot(
               x = 'region',
               y = 'share',
               kind='bar',
               rot=90,
               legend=False,
               title=f'Доля вернувшихся пользователей по названиям регионов')

plt.xlabel('Название региона')
plt.ylabel('Доля вернувшихся пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Гипотеза не верна. `Каменевский регион` чаще выбирают для посещения мероприятий, но доля вернувшихся пользователей в этом регионе не выше чем в других регионах. Например, доля вернувшихся пользователей выше в регионах: `Широковская область`, `Шанырский регион`.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут аналогично нужно переработать выводы, так как они сделаны по некорректным данным.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут тоже актуально - доли должны быть примерно в диапазоне 60%, как в среднем по выборке.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
data_false = user_profiles_filtered[user_profiles_filtered['is_two'] == False]['avg_order_costs']
data_true = user_profiles_filtered[user_profiles_filtered['is_two'] == True]['avg_order_costs']

print("Группа is_two = False:")
print(data_false.describe())

print("\nГруппа is_two = True:")
print(data_true.describe())
# Out:
# Группа is_two = False:
# count    8368.000000
# mean      545.295638
# std       519.514095
# min       -10.770000
# 25%       132.070000
# 50%       378.030000
# 75%       830.317500
# max      2628.420000
# Name: avg_order_costs, dtype: float64
#
# Группа is_two = True:
# count    13270.000000
# mean       544.337162
# std        369.354477
# min         -5.380000
# 25%        270.815000
# 50%        495.775000
# 75%        745.167500
# max       2628.420000
# Name: avg_order_costs, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.hist(data_false, 
        bins=30, 
        density=True,
        alpha=0.7, 
        color='skyblue', 
        label='1 заказ',
        edgecolor='black', 
        linewidth=0.5)
ax.hist(data_true, 
        bins=30, 
        density=True,
        alpha=0.7, 
        color='salmon', 
        label='2 и более заказа',
        edgecolor='black',
        linewidth=0.5)

ax.set_title('Нормированные гистограммы распределения avg_order_costs\nпо группам is_two', 
              fontsize=16, pad=20)
ax.set_xlabel('Средняя выручка с заказа (avg_order_costs)', fontsize=12)
ax.set_ylabel('Плотность вероятности', fontsize=12)
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# Вывод:
# 1. Группа `is_two = False` характеризуется большим количеством заказов с минимальной выручкой, пик распредления приходится на значение от 0 до 100 руб.
# 2. Группа `is_two = True` характеризуется большим количеством заказов от 400 до 700 рублей. В этой группе средний чек выше чем в группе `is_two = False`.
# 3. У группы `is_two = False` асимметрия выражена сильнее — значительная доля заказов сосредоточена у нулевой отметки.
# 4. Группа `is_two = False` демонстрирует большую концентрацию «неприбыльных» или малоприбыльных заказов.
# 5. Группа `is_two = True` отличается большей стабильностью в плане выручки (хотя и с большим разбросом).

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Задание выполнен некорректно - тут нужно исследовать распределение `avg_order_costs` в разрезе `is_two` с помощью нормированной гистограммы. Сейчас ты сделал анализ структуры `avg_order_costs` по `service_name` в разрезе `is_two` - это не то, что требовалось в задании.
#
# Обрати внимание на важность нормирования гистограмм.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Интерпретация полученного графика выполнена верно: ты точно определил диапазоны, где концентрируются пользователи, и заметил смещение пика трат у вернувшейся аудитории в сторону более дорогих покупок. Описание различий между группами логичное и последовательное.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В легенде графика стоит использовать понятные названия категорий, например «1 заказ» и «2+ заказа», вместо технических обозначений is_two = True и is_two = False. Это сделает визуализацию наглядной для любого читателя без необходимости пояснять, что значит переменная.

# %% [markdown]
# ---
#
# **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
filtered_2_4 = user_profiles_filtered[(user_profiles_filtered['is_two'] == True) & (user_profiles_filtered['is_five'] == False)]['avg_order_costs']
filtered_5 = user_profiles_filtered[user_profiles_filtered['is_five'] == True]['avg_order_costs']


print("Группа is_two = False:")
print(filtered_2_4.describe())

print("\nГруппа is_two = True:")
print(filtered_5.describe())
# Out:
# Группа is_two = False:
# count    7147.000000
# mean      551.572374
# std       420.197702
# min        -5.380000
# 25%       218.425000
# 50%       471.270000
# 75%       798.550000
# max      2628.420000
# Name: avg_order_costs, dtype: float64
#
# Группа is_two = True:
# count    6123.000000
# mean      535.891945
# std       299.089588
# min         0.000000
# 25%       330.455000
# 50%       512.650000
# 75%       700.810000
# max      2299.870000
# Name: avg_order_costs, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax.hist(filtered_2_4, 
        bins=30, 
        density=True,
        alpha=0.7, 
        color='skyblue', 
        label='2-4 заказа',
        edgecolor='black', 
        linewidth=0.5)
ax.hist(filtered_5, 
        bins=30, 
        density=True,
        alpha=0.7, 
        color='salmon', 
        label='5 и более заказов',
        edgecolor='black',
        linewidth=0.5)

ax.set_title('Нормированные гистограммы распределения avg_order_costs\nпо сегментам', 
              fontsize=16, pad=20)
ax.set_xlabel('Средняя выручка с заказа (avg_order_costs)', fontsize=12)
ax.set_ylabel('Плотность вероятности', fontsize=12)
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# Пользователи, совершившие 5 и более заказов, чаще имеют низкую среднюю выручку с заказа (концентрация в диапазоне 400–700 рублей), длинный "хвост" распределения меньше чем у пользователей совершивших 2-4 заказа. Более лояльная аудитория показывает более стабильную среднюю выручку с заказа.
# Пользователи, совершившие 2–4 заказа, в среднем тратят меньше на заказ (пик около 0 - 100 рублей), но среди них есть значительная доля высокотратящих пользователей (длинный «хвост» распределения).

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Здесь та же ошибка, что и в прошлом задании.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно подметил разницу в форме «хвостов» распределения: у менее активных пользователей действительно чаще встречаются аномально высокие чеки, а выборка лояльных пользователей более однородна.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В выводах есть логическое противоречие и ошибка интерпретации графика. Ты пишешь, что пользователи с 5+ заказами «более экономные», но при этом указываешь, что их концентрация находится в диапазоне 400–700 рублей. В то же время для группы 2–4 заказа ты определяешь пик в районе 100–500 рублей (на графике видно, что самый высокий столбец у синей группы вообще в диапазоне 0–100).
#
# Если пик у группы 2–4 находится левее (ближе к нулю), чем у группы 5+, это значит, что пользователи с малым числом заказов чаще совершают дешевые покупки. Лояльные пользователи (5+), судя по графику, как раз тратят больше и стабильнее (их «горб» смещен вправо), просто среди них нет тех, кто совершает разовые сверхдорогие покупки. Вывод нужно скорректировать: лояльная аудитория демонстрирует более высокий стабильный чек, а не «экономность».

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
user_profiles_filtered['avg_tickets_count'].describe()
# Out:
# count    21638.000000
# mean         2.743327
# std          0.917496
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.100000
# max         11.000000
# Name: avg_tickets_count, dtype: float64

# %%
plt.figure(figsize=(12, 6))
user_profiles_filtered['avg_tickets_count'] = user_profiles_filtered['avg_tickets_count'].round(1)
sns.countplot(data = user_profiles_filtered, x = 'avg_tickets_count')
plt.title('Распределение пользователей по среднему количесву билетов в заказе')
plt.xlabel('Среднее количество билетов в заказе')
plt.ylabel('Число пользователей')
plt.xticks(rotation=90)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Для анализа распределения дискретных признаков нужен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Распределение неравновмерное. Видны всплески по количеству пользователей у которых в среднем: 3, 2, 4 и 1 билет.

# %%
def segmentation(avg_tickets_count):
    if 1 <= avg_tickets_count < 2:
        return 'от 1 до 2 билетов'
    elif 2 <= avg_tickets_count < 3:
        return 'от 2 до 3 билетов'
    elif 3 <= avg_tickets_count < 5:
        return 'от 3 до 5 билетов'
    else:
        return 'от 5 и более билетов'
    
user_profiles_filtered['segment'] = user_profiles_filtered['avg_tickets_count'].apply(segmentation)
grouped_segment = user_profiles_filtered.groupby('segment').agg(total_users = ('user_id','count'), repeat_users = ('is_two','sum')).reset_index()
grouped_segment['repeat_rate'] = (grouped_segment['repeat_users'] / grouped_segment['total_users']).round(2)
grouped_segment
# Out:
#                 segment  total_users  repeat_users  repeat_rate
# 0     от 1 до 2 билетов         2415          1237         0.51
# 1     от 2 до 3 билетов         9450          6941         0.73
# 2     от 3 до 5 билетов         9112          4968         0.55
# 3  от 5 и более билетов          661           124         0.19

# %% [markdown]
# Сегменты `от 1 до 2 билетов` и `от 3 до 5 билетов` имеют приблизительно равные доли пользователей совершивших повторный заказ. Сегмент `от 2 до 3 билетов` имеет наибольшую долю пользователей совершивших повторный заказ. Наименьшая доля у сегмента `от 5 и более билетов`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно подметил сходство показателей между первым и третьим сегментами, а также правильно определил группы с самой высокой и самой низкой возвращаемостью.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Ты пропустил одну часть задания. В вопросах требовалось описать не только долю повторных покупок, но и само распределение пользователей по сегментам - равномерно оно или сконцентрировано.
#
# Не выполнена также первая часть задания `Изучите распределение пользователей по среднему количеству билетов в заказе (avg_tickets_count) и опишите основные наблюдения` - она предполагает анализ `avg_tickets_count` без учёта сегментации.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> По первой части актуально - нужно явно указать, равномерное или сконцентрированное у нас распределение билетов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
user_profiles_filtered['weekday'] = user_profiles_filtered['first_order'].dt.dayofweek
user_profiles_filtered['weekday_name'] = user_profiles_filtered['first_order'].dt.day_name()

result = user_profiles_filtered.groupby('weekday_name').agg(total_users=('user_id', 'count'),repeat_users=('is_two', 'sum')).reset_index()
result['repeat_ratio'] = (result['repeat_users'] / result['total_users']).round(2)

days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
result['weekday_name'] = pd.Categorical(result['weekday_name'], categories=days, ordered=True)
result = result.sort_values('weekday_name').reset_index(drop=True)
result
# Out:
#   weekday_name  total_users  repeat_users  repeat_ratio
# 0       Monday         2930          1847          0.63
# 1      Tuesday         3176          1966          0.62
# 2    Wednesday         3057          1901          0.62
# 3     Thursday         3113          1850          0.59
# 4       Friday         3259          1950          0.60
# 5     Saturday         3326          2089          0.63
# 6       Sunday         2777          1667          0.60

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.barplot(data=result, x='weekday_name', y='total_users', palette='Blues')
plt.title('Общее число пользователей по дням недели')
plt.ylabel('Количество пользователей')
plt.xlabel('День недели')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
sns.lineplot(data=result, x='weekday_name', y='repeat_ratio', marker='o', color='red')
plt.title('Доля пользователей с повторными заказами')
plt.ylabel('Доля повторных заказов')
plt.xlabel('День недели')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.ylim(0.3, 0.8)

plt.tight_layout()
plt.show()

# %% [markdown]
# День недели в которую совершена первая покупка, не влияет на возврат пользователя. Например, в понедельник количество пользователей совершивших первую покупку меньше чем во вторник. Доля вернувшихся пользователей которые совершили первую покупку в понедельник больше, чем во вторник.
#
# Наибольшая доля вернувшихся пользователей в понедельник и в субботу.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно сформировал таблицу с метриками. Расчеты доли повторных покупок выполнены правильно и соответствуют исходным данным.
#
# Визуализация построена грамотно: на графиках дни недели отсортированы в правильном хронологическом порядке (с понедельника по воскресенье), несмотря на то, что в таблице индексы идут вразнобой. Данные на графиках полностью совпадают с табличными значениями.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание на индексную колонку в таблице (цифры слева). Сейчас они идут хаотично: 1, 5, 6, 4, 0... Лучше отсортировать таблицу по хронологии дней недели, чтобы данные было удобнее читать.
#
# На линейном графике ось Y начинается с 0.59, из-за чего колебания кажутся очень резкими. Это не ошибка, но такой масштаб может вводить в заблуждение относительно значимости изменений.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Вывод получился слишком кратким. В задании стоял конкретный вопрос: влияет ли день недели на вероятность возврата. Ты лишь констатировал факт о том, в какие дни доля максимальна. Чтобы ответ был полным, стоит явно написать, есть ли влияние.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ---
#
# **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
def total_orders(total_orders):
    if 2 <= total_orders <= 4:
        return '2-4 заказа'
    elif total_orders >= 5:
        return 'от 5 и более заказов'
    else:
        return None

filtered = user_profiles_filtered[user_profiles_filtered['avg_days_since_prev'] >= 0].copy()
filtered['avg_days_since_prev'] = filtered['avg_days_since_prev'].astype('float64')
filtered['total_orders_group'] = filtered['total_orders'].apply(total_orders)
result = filtered.groupby('total_orders_group').agg(avg_days=('avg_days_since_prev', 'mean'),repeat_users=('is_two', 'sum')).reset_index()
result['avg_days'] = result['avg_days'].round(2)
result.head()
# Out:
#      total_orders_group  avg_days  repeat_users
# 0            2-4 заказа     21.33          7147
# 1  от 5 и более заказов      9.90          6123

# %% [markdown]
# При увеличении общего числа заказов, интервал между ними сокращается более  чем в 2 раза.
# В сегменте `от 5 и более заказов` средний интервал между заказами 9.9 дней.

# %%
fig, ax = plt.subplots(figsize=(14, 7))

sns.histplot(
    data=filtered[filtered['total_orders_group'] == '2-4 заказа'],
    x='avg_days_since_prev',
    ax=ax,
    label='2–4 заказа',
    color='skyblue',
    fill=True,
    alpha=0.4,
    stat='density'
)

sns.histplot(
    data=filtered[filtered['total_orders_group'] == 'от 5 и более заказов'],
    x='avg_days_since_prev',
    ax=ax,
    label='5+ заказов',
    color='salmon',
    fill=True,
    alpha=0.4,
    stat='density'
)

ax.set_title('Сравнение плотностей распределения интервалов между заказами')
ax.set_xlabel('Дни между заказами')
ax.set_ylabel('Плотность вероятности')
plt.legend()
ax.xaxis.set_major_locator(MultipleLocator(base=5))
plt.show()

# %% [markdown]
# У группы `2-4 заказа` ярко выражен пик вероятности от 0 до 5 дней между заказами. Можно сказать, что пользователи этой группы, чаще всего делаю повторый заказ почти сразу после предыдущей покупки. Дальний хвост: значительное число клиентов имеет большие интервалы между заказами (до 140+ дней), что указывает на нерегулярность поведения.
# У группы `5 и более заказов` форма распределения более компактная, можно сказать, что пользователи сосредоточены в интервале от 0 до 15 дней. Клиенты с 5 и более заказами формируют привычку пользоваться сервисом, их поведение более предсказуемо.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты верно выполнил техническую часть задания: пользователи правильно разделены на две группы (2-4 заказа и 5+ заказов). Расчет метрик выглядит корректно и логично - у лояльной аудитории интервал между покупками ожидаемо ниже. Цифра в текстовом комментарии соответствует данным в таблице.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Текстовый вывод сейчас неполный. Ты привел данные только по одной группе, хотя смысл аналитики - в сравнении. Стоит явно написать, что при увеличении общего числа заказов средний интервал между ними сокращается более чем в два раза (с 18 до 9 дней).
#
# Ты также пропустил вторую, аналитическую часть задания. Требовалось не просто посчитать цифры, а сделать вывод о том, как интервал влияет на удержание клиентов. Сейчас в выводе просто констатация факта («интервал 8.9 дней»), но нет ответа на вопрос «как это влияет».
#
# Для этого можно исследовать распределение `avg_days_since_prev` в разрезе выделенных групп с помощью нормированной гистограммы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> График нужно наложить друг на друга, чтобы сравнение было более наглядным.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Графики нужно нормировать.

# %% [markdown]
# ---
#
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %%
interval_cols = ['avg_order_costs','avg_tickets_count', 'avg_days_since_prev']
cols = ['region','avg_order_costs','avg_tickets_count', 'avg_days_since_prev','service_name', 'genre_event', 'device']
user_profiles_filtered_correlation = user_profiles_filtered.drop(columns=['user_id'])
correlation_matrix = user_profiles_filtered_correlation.phik_matrix(interval_cols=interval_cols)
corr_with_orders = correlation_matrix.loc[cols, 'total_orders'].sort_values(ascending=False)
print(corr_with_orders)
# Out:
# avg_days_since_prev    0.493115
# region                 0.410223
# avg_tickets_count      0.285403
# avg_order_costs        0.254385
# device                 0.066900
# service_name           0.000000
# genre_event            0.000000
# Name: total_orders, dtype: float64

# %%
corr_df = corr_with_orders.to_frame()
plt.figure(figsize=(6, 4))
sns.heatmap(corr_df, annot=True, cmap='coolwarm', center=0)
plt.title('Корреляция total_orders')
plt.show()

# %% [markdown]
# Наиболее связанные признаки с `total_orders` это среднее время между заказами, регион в котором прошло мероприятие, среднее количество билетов в заказе и средний чек заказа. Так как при первом анализе есть данные с 0 значением, проведем сегментацию.

# %%
def order_segment(total_orders):
    if total_orders == 1:
        return '1 заказ'
    elif 2 <= total_orders <= 4:
        return 'от 2 до 4'
    elif total_orders >= 5:
        return 'от 5 и выше'
user_profiles_filtered['order_segment'] = user_profiles_filtered['total_orders'].apply(order_segment)
segments = ['1 заказ', 'от 2 до 4', 'от 5 и выше']

for segment in segments:
    segment_data = user_profiles_filtered[user_profiles_filtered['order_segment'] == segment].drop(columns=['user_id'])
    if segment != '1 заказ':
        correlation_matrix = segment_data.phik_matrix(interval_cols=interval_cols)
        corr_with_orders = correlation_matrix.loc[cols, 'total_orders'].sort_values(ascending=False)
        print(f"\nКорреляция для сегмента '{segment}':")
        print(corr_with_orders)
    
        corr_df = corr_with_orders.to_frame()
        plt.figure(figsize=(6, 4))
        sns.heatmap(corr_df, annot=True, cmap='coolwarm', center=0)
        plt.title(f'Корреляция total_orders (сегмент "{segment}")')
        plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable is_five for analysis 1. Dropping this column
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable is_two for analysis 1. Dropping this column
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\phik\data_quality.py:82: UserWarning: Not enough unique value for variable order_segment for analysis 1. Dropping this column
#   warnings.warn(
# Корреляция для сегмента 'от 2 до 4':
# avg_tickets_count      0.393111
# avg_days_since_prev    0.385223
# avg_order_costs        0.108758
# service_name           0.064842
# device                 0.009622
# region                 0.000000
# genre_event            0.000000
# Name: total_orders, dtype: float64
# ...

# %% [markdown]
# Корреляция сегмента с 1 заказом невозможна, так как все значения будут принимать 1.
# В сегменте от 2 до 4 заказов набольшая корреляция у среднего количество дней от предыдущей покупки пользователя и средней стоимости билетов.
# В сегменте от 5 и более заказов наибольшая корреляция у среднего количество дней от предыдущей покупки пользователя и региона проведения мероприятия.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты успешно справился с технической частью: рассчитал коэффициент Phi_k и построил тепловую карту. Вывод корректно отражает данные с визуализации - ты верно выделил признаки с наиболее высокими показателями связи (среднее время между заказами и регион).

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание на название графика: там написано «с интервальными признаками», хотя в списке есть и категориальные переменные (регион, девайс). Это вводит в небольшое заблуждение относительно состава данных.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Ты упустил важную часть задания, касающуюся сегментации. В условии сказано: если значения связи близки к нулю (а у тебя genre_event и service_name равны 0), нужно проверить разброс данных и выделить сегменты («1 заказ», «от 2 до 4», «от 5 и выше»), после чего повторить анализ.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# #### Вывод
#
# Из базы данных через SQL запрос была получена информация из Яндекс Афиши.
#
# Был сформирован изначальный датафрейм `df` в котором было 290611 строк.
#
# Был предоставлен датасет `final_tickets_tenge_df.csv` с курсом тенге к рублю за 24 год.
#
# Объединили два датафрейма в один `df_merged` для приведения всех цен к одной валюте - рублю. Была создана колонка `revenue_rub`.
#
# Далее был исследован датафрейм `df_merged` на дубликаты и выбросы. Были замечены выбросы в колонке `revenue_rub`. Была проведена оптимизация датафрейма.
#
# После предобработки мы получили датафрейм `df_filtered` который уменьшился на 2825 строк.

# %% [markdown]
# Сотставили профиль каждого пользователя `user_profiles`, всего в выборке было 21854 пользователей. После фильтрации по количеству заказов пользователей стало 21638.
#
# Доля пользователей, совершивших 2 и более заказа: 61.71
# Доля пользователей, совершивших 5 и более заказов: 29.01
#
# Признаки связанные с возвратом покупателя:
# 1. Тип приложения - пользователи совершившие заказ через `мобильное` приложение чаще возвращаются.
# 2. Регион проведения мероприятия - `Каменевский регион` чаще выбирают для посещения мероприятий, но доля вернувшихся пользователей в этом регионе не выше чем в других регионах.  Доля вернувшихся пользователей выше в регионах: `Широковская область`, `Шанырский регион`.
# 3. Тип меропрития - наибольшее количество вернувшихся пользователей покупали билеты на концерты.
# 4. Название сервиса на котором приобрели билеты - `Билеты без проблем` и `Мой билет` являются наиболее популярными у вернувшихся пользователей.

# %% [markdown]
# Пользователи, совершившие 5 и более заказов, чаще имеют низкую среднюю выручку с заказа (концентрация в диапазоне 400–700), длинный "хвост" распределения меньше чем у пользователей совершивших 2-4 заказа.
#
# Пользователи, совершившие 2–4 заказа, в среднем тратят меньше на заказ (пик около 0 - 100), но среди них есть значительная доля высокотратящих пользователей (длинный «хвост» распределения).
#
# Наибольшая доля вернувшихся пользователей делали свои первые заказы в `Понедельник` и `Субботу`.
#
# Сильную корреляционную связь с количеством заказов имеют: среднее количество дней между заказами и среднее количество билетов в заказе

# %% [markdown]
# #### Рекомендации
#
# 1. Необходимо обратить внимание на пользователей совершающих покупки через десктопное устройство.
# 2. Обратить внимание на другие регионы проведения мероприятий.
# 3. Обратить внимание на другие типы мероприятий. Приложить больше маркенговых усилий для рекламы других мероприятий.
# 4. Обратить внимание на сервисы по продажам билетов. Прорекламировать другие сервисы или изменить ценовую политику, добавив скидки, программу лояльности и т.д.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Вывод нужно актуализировать с учётом замечаний.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Пока актуально в свете текущих замечаний о долях возврата.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# **Вставьте ссылку на проект в этой ячейке тетрадки перед отправкой проекта на ревью.**
#
# https://github.com/SlowAki9/Projects

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Отсутствует ссылка на репозиторий - пришли, пожалуйста, на следующую итерацию.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В репозитории размещены все файлы проекта.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Можно также добавить файл `README.md` и указать там промежуточный вывод.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В версии, которую ты заливаешь на `GitHub`, не стоит оставлять параметры подключения в явном виде - это может привести к несанкционированному доступу к данным, что чревато их потереей или изменением. Лучшее решение - локально создать `.env` файл, из которого с помощью `os` эти параметры подключения передаются в код. А файл `.gitignore` поможет не отслеживать этот файл для репозитория.
#
# Файл `.env` может выглядеть так:
#
# ```python
# DB_NAME="..."
# DB_HOST="..."
# DB_PORT="..."
# DB_USER="..."
# DB_PASSWORD="..."
# ```
#
# В самом проекте мы можем обращаться к сохраненным параметрам с помощью библиотеки `dotenv`, чтобы загрузить переменные окружения, и `os`, чтобы обратиться к ним:
#
# ```python
# import os
# import dotenv
#
# load_dotenv() # автоматически ищет .env в текущей директории
#
# connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
#     os.getenv('DB_USER'),
#     os.getenv('DB_PASSWORD'),
#     os.getenv('DB_HOST'),
#     os.getenv('DB_PORT'),
#     os.getenv('DB_NAME'),
# )
# ```
#
# Также нужно удалить параметры подключения из описания проекта.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Захар, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)
